# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span></li><li><span><a href="#Цели-исследования" data-toc-modified-id="Цели-исследования-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Цели исследования</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Описание данных</a></span></li><li><span><a href="#План-исследования" data-toc-modified-id="План-исследования-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>План исследования</a></span></li><li><span><a href="#Подключение-к-базе-данных" data-toc-modified-id="Подключение-к-базе-данных-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Подключение к базе данных</a></span></li><li><span><a href="#Чтение-таблиц" data-toc-modified-id="Чтение-таблиц-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чтение таблиц</a></span></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Cколько-книг-вышло-после-1-января-2000-года?" data-toc-modified-id="Cколько-книг-вышло-после-1-января-2000-года?-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Cколько книг вышло после 1 января 2000 года?</a></span></li><li><span><a href="#Для-каждой-книги-посчитаем-количество-обзоров-и-среднюю-оценку" data-toc-modified-id="Для-каждой-книги-посчитаем-количество-обзоров-и-среднюю-оценку-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Для каждой книги посчитаем количество обзоров и среднюю оценку</a></span></li><li><span><a href="#Определим-издательство,-которое-выпустило-наибольшее-число-книг-толще-50-страниц-—-так-мы-исключим-из-анализа-брошюры" data-toc-modified-id="Определим-издательство,-которое-выпустило-наибольшее-число-книг-толще-50-страниц-—-так-мы-исключим-из-анализа-брошюры-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Определим издательство, которое выпустило наибольшее число книг толще 50 страниц — так мы исключим из анализа брошюры</a></span></li><li><span><a href="#Определим-автора-с-самой-высокой-средней-оценкой-книг-—-учитываем-только-книги-с-50-и-более-оценками" data-toc-modified-id="Определим-автора-с-самой-высокой-средней-оценкой-книг-—-учитываем-только-книги-с-50-и-более-оценками-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>Определим автора с самой высокой средней оценкой книг — учитываем только книги с 50 и более оценками</a></span></li><li><span><a href="#Посчитаем-среднее-количество-обзоров-от-пользователей,-которые-поставили-больше-48-оценок" data-toc-modified-id="Посчитаем-среднее-количество-обзоров-от-пользователей,-которые-поставили-больше-48-оценок-7.5"><span class="toc-item-num">7.5&nbsp;&nbsp;</span>Посчитаем среднее количество обзоров от пользователей, которые поставили больше 48 оценок</a></span></li></ul></li><li><span><a href="#Дополнительные-задания" data-toc-modified-id="Дополнительные-задания-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Дополнительные задания</a></span><ul class="toc-item"><li><span><a href="#Выведи-таблицу,-которая-будет-содержать-по-году-публикации-(отобразить-нужно-только-те-года,-в-которых-издано-более-30-книг):" data-toc-modified-id="Выведи-таблицу,-которая-будет-содержать-по-году-публикации-(отобразить-нужно-только-те-года,-в-которых-издано-более-30-книг):-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Выведи таблицу, которая будет содержать по году публикации (отобразить нужно только те года, в которых издано более 30 книг):</a></span></li><li><span><a href="#Выведи-в-одной-таблице-два-числа-—-среднюю-оценку-тех-книг,-на-которые-написало-отзывов-более-3-человек-и-отдельно-среднюю-оценку-остальных-книг,-сделай-выводы,-какой-рейтинг-больше" data-toc-modified-id="Выведи-в-одной-таблице-два-числа-—-среднюю-оценку-тех-книг,-на-которые-написало-отзывов-более-3-человек-и-отдельно-среднюю-оценку-остальных-книг,-сделай-выводы,-какой-рейтинг-больше-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Выведи в одной таблице два числа — среднюю оценку тех книг, на которые написало отзывов более 3 человек и отдельно среднюю оценку остальных книг, сделай выводы, какой рейтинг больше</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Выводы</a></span></li></ul></div>

# %% [markdown]
# ## Описание проекта

# %% [markdown]
#   *Коронавирус застал мир врасплох, изменив привычный порядок вещей. В свободное время жители городов больше не выходят на улицу, не посещают кафе и торговые центры. Зато стало больше времени для книг. Это заметили стартаперы — и бросились создавать приложения для тех, кто любит читать.*
#
#   *Наша компания решила быть на волне и купила крупный сервис для чтения книг по подписке. Наша первая задача как аналитика — проанализировать базу данных.*
#   *В ней — информация о книгах, издательствах, авторах, а также пользовательские обзоры книг. Эти данные помогут сформулировать ценностное предложение для нового продукта.*

# %% [markdown]
# ## Цели исследования

# %% [markdown]
# - Анализ базы данных

# %% [markdown]
# ## Описание данных

# %% [markdown]
# **Таблица `books`**
#
# Содержит данные о книгах:
#
# - `book_id` — идентификатор книги;
# - `author_id` — идентификатор автора;
# - `title` — название книги;
# - `num_pages` — количество страниц;
# - `publication_date` — дата публикации книги;
# - `publisher_id` — идентификатор издателя.
#
# **Таблица `authors`**
#
# Содержит данные об авторах:
#
# - `author_id` — идентификатор автора;
# - `author` — имя автора.
#
# **Таблица `publishers`**
#
# Содержит данные об издательствах:
#
# - `publisher_id` — идентификатор издательства;
# - `publisher` — название издательства;
#
# **Таблица `ratings`**
#
# Содержит данные о пользовательских оценках книг:
#
# - `rating_id` — идентификатор оценки;
# - `book_id` — идентификатор книги;
# - `username` — имя пользователя, оставившего оценку;
# - `rating` — оценка книги.
#
# **Таблица `reviews`**
#
# Содержит данные о пользовательских обзорах на книги:
#
# - `review_id` — идентификатор обзора;
# - `book_id` — идентификатор книги;
# - `username` — имя пользователя, написавшего обзор;
# - `text` — текст обзора.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## План исследования

# %% [markdown]
# - Посчитать, сколько книг вышло после 1 января 2000 года;
# - Для каждой книги посчитать количество обзоров и среднюю оценку;
# - Определить издательство, которое выпустило наибольшее число книг толще 50 страниц — так мы исключим из анализа брошюры;
# - Определить автора с самой высокой средней оценкой книг — учитываем только книги с 50 и более оценками;
# - Посчитать среднее количество обзоров от пользователей, которые поставили больше 48 оценок.

# %% [markdown]
# ## Подключение к базе данных

# %%
# импортируем библиотеки
import pandas as pd
from sqlalchemy import text, create_engine

# %%
# устанавливаем параметры
db_config = {'user': 'praktikum_student', # имя пользователя
'pwd': 'Sdf4$2;d-d30pp', # пароль
'host': 'rc1b-wcoijxj3yxfsf3fs.mdb.yandexcloud.net',
'port': 6432, # порт подключения
'db': 'data-analyst-final-project-db'} # название базы данных
connection_string = 'postgresql://{user}:{pwd}@{host}:{port}/{db}'.format(**db_config)

# сохраняем коннектор
engine = create_engine(connection_string, connect_args={'sslmode':'require'})

# %% [markdown]
# ## Чтение таблиц

# %%
query = ''' SELECT *
            FROM books LIMIT 10
        '''
con=engine.connect()

pd.io.sql.read_sql(sql=text(query), con = con)
# Out:
#    book_id  author_id                                              title  \
# 0        1        546                                       'Salem's Lot
# 1        2        465                 1 000 Places to See Before You Die
# 2        3        407  13 Little Blue Envelopes (Little Blue Envelope...
# 3        4         82  1491: New Revelations of the Americas Before C...
# 4        5        125                                               1776
# 5        6        257               1st to Die (Women's Murder Club  #1)
# 6        7        258               2nd Chance (Women's Murder Club  #2)
# 7        8        260              4th of July (Women's Murder Club  #4)
# 8        9        563                                   A Beautiful Mind
# 9       10        445                                 A Bend in the Road
#
#    num_pages publication_date  publisher_id
# 0        594       2005-11-01            93
# 1        992       2003-05-22           336
# ...

# %%
query = ''' SELECT COUNT(*)
          FROM books 
''' 
con=engine.connect()

pd.io.sql.read_sql(sql=text(query), con = con)
# Out:
#    count
# 0   1000

# %%
query = ''' SELECT *
            FROM authors LIMIT 10
        '''
con=engine.connect()

pd.io.sql.read_sql(sql=text(query), con = con)
# Out:
#    author_id                                author
# 0          1                            A.S. Byatt
# 1          2        Aesop/Laura Harris/Laura Gibbs
# 2          3                       Agatha Christie
# 3          4                         Alan Brennert
# 4          5              Alan Moore/David   Lloyd
# 5          6                            Alan Paton
# 6          7           Albert Camus/Justin O'Brien
# 7          8                         Aldous Huxley
# 8          9    Aldous Huxley/Christopher Hitchens
# 9         10  Aleksandr Solzhenitsyn/H.T. Willetts

# %%
query = ''' SELECT COUNT(*)
          FROM authors 
''' 
con=engine.connect()

pd.io.sql.read_sql(sql=text(query), con = con)
# Out:
#    count
# 0    636

# %%
query = ''' SELECT *
            FROM publishers LIMIT 10
        '''
con=engine.connect()

pd.io.sql.read_sql(sql=text(query), con = con)
# Out:
#    publisher_id                                publisher
# 0             1                                      Ace
# 1             2                                 Ace Book
# 2             3                                Ace Books
# 3             4                            Ace Hardcover
# 4             5        Addison Wesley Publishing Company
# 5             6                                  Aladdin
# 6             7                       Aladdin Paperbacks
# 7             8                             Albin Michel
# 8             9                          Alfred A. Knopf
# 9            10  Alfred A. Knopf Books for Young Readers

# %%
query = ''' SELECT COUNT(*)
          FROM publishers 
''' 
con=engine.connect()

pd.io.sql.read_sql(sql=text(query), con = con)
# Out:
#    count
# 0    340

# %%
query = ''' SELECT *
            FROM ratings LIMIT 10
'''
con=engine.connect()

pd.io.sql.read_sql(sql=text(query), con = con)
# Out:
#    rating_id  book_id       username  rating
# 0          1        1     ryanfranco       4
# 1          2        1  grantpatricia       2
# 2          3        1   brandtandrea       5
# 3          4        2       lorichen       3
# 4          5        2    mariokeller       2
# 5          6        3  johnsonamanda       4
# 6          7        3    scotttamara       5
# 7          8        3    lesliegibbs       5
# 8          9        4    abbottjames       5
# 9         10        4   valenciaanne       4

# %%
query = ''' SELECT COUNT(*)
          FROM ratings 
''' 
con=engine.connect()

pd.io.sql.read_sql(sql=text(query), con = con)
# Out:
#    count
# 0   6456

# %%
query = ''' SELECT *
            FROM reviews LIMIT 10
        '''
con=engine.connect()

pd.io.sql.read_sql(sql=text(query), con = con)
# Out:
#    review_id  book_id       username  \
# 0          1        1   brandtandrea
# 1          2        1     ryanfranco
# 2          3        2       lorichen
# 3          4        3  johnsonamanda
# 4          5        3    scotttamara
# 5          6        3    lesliegibbs
# 6          7        4   valenciaanne
# 7          8        4    abbottjames
# 8          9        5        npowers
# 9         10        5        staylor
#
#                                                 text
# 0  Mention society tell send professor analysis. ...
# 1  Foot glass pretty audience hit themselves. Amo...
# 2  Listen treat keep worry. Miss husband tax but ...
# 3  Finally month interesting blue could nature cu...
# 4  Nation purpose heavy give wait song will. List...
# 5           Analysis no several cause international.
# 6  One there cost another. Say type save. With pe...
# 7  Within enough mother. There at system full rec...
# 8  Thank now focus realize economy focus fly. Ite...
# ...

# %%
query = ''' SELECT COUNT(*)
          FROM reviews 
''' 
con=engine.connect()

pd.io.sql.read_sql(sql=text(query), con = con)
# Out:
#    count
# 0   2793

# %% [markdown]
# - Таблицы открыли, посмотрели.

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Cколько книг вышло после 1 января 2000 года?

# %%
query = '''SELECT COUNT(book_id) FROM books WHERE publication_date > '2000-01-01' '''

con=engine.connect()

pd.io.sql.read_sql(sql=text(query), con = con)
# Out:
#    count
# 0    819

# %% [markdown]
# - После 1 января вышло 819 книг.

# %% [markdown]
# ### Для каждой книги посчитаем количество обзоров и среднюю оценку

# %%
query = '''SELECT
        ratings.book_id AS book_id,
        COUNT(reviews.text) AS total_reviews,
        AVG(ratings.rating) AS mean_rating
        FROM
            ratings
        LEFT JOIN reviews ON 
            (reviews.book_id = ratings.book_id
            AND reviews.username = ratings.username)
        GROUP BY ratings.book_id
        ORDER BY mean_rating DESC           
            
'''

con=engine.connect()

pd.io.sql.read_sql(sql=text(query), con = con)
# Out:
#      book_id  total_reviews  mean_rating
# 0        518              2         5.00
# 1        732              2         5.00
# 2        347              2         5.00
# 3        610              2         5.00
# 4        330              1         5.00
# ..       ...            ...          ...
# 995      915              3         2.25
# 996      371              2         2.00
# 997      316              2         2.00
# 998      202              3         2.00
# 999      303              2         1.50
#
# [1000 rows x 3 columns]

# %%
query = ''' SELECT book_id, reviews        
        FROM reviews
        WHERE book_id = 518;
       

            
'''

con=engine.connect()

pd.io.sql.read_sql(sql=text(query), con = con)
# Out:
#    book_id                                            reviews
# 0      518  (1430,518,znelson,"Degree nation since late pa...
# 1      518  (1431,518,timothygibson,"Look worker director ...

# %%
query = ''' with start_data as (
SELECT b.title,
b.book_id,
rw."text" reviews
FROM REVIEWS AS rw
RIGHT OUTER JOIN BOOKS AS b ON rw.book_id=b.book_id
LEFT OUTER JOIN RATINGS AS r ON b.book_id = r.book_id
)
       
select * from start_data
where book_id = 518
            
'''

con=engine.connect()

pd.io.sql.read_sql(sql=text(query), con = con)
# Out:
#                                   title  book_id  \
# 0  Pop Goes the Weasel (Alex Cross  #5)      518
# 1  Pop Goes the Weasel (Alex Cross  #5)      518
# 2  Pop Goes the Weasel (Alex Cross  #5)      518
# 3  Pop Goes the Weasel (Alex Cross  #5)      518
#
#                                              reviews
# 0                 Look worker director instead back.
# 1  Degree nation since late pattern author. Admit...
# 2                 Look worker director instead back.
# 3  Degree nation since late pattern author. Admit...

# %%
query = ''' SELECT b.title,
       COUNT (DISTINCT rw.review_id) AS total_reviews, ROUND (avg(r.rating), 2) AS mean_rating
       FROM REVIEWS AS rw
       RIGHT OUTER JOIN BOOKS AS b ON rw.book_id=b.book_id
       LEFT OUTER JOIN RATINGS AS r ON b.book_id = r.book_id
       GROUP BY b.book_id
       ORDER BY mean_rating DESC

            
'''

con=engine.connect()

pd.io.sql.read_sql(sql=text(query), con = con)
# Out:
#                                                  title  total_reviews  \
# 0        Arrows of the Queen (Heralds of Valdemar  #1)              2
# 1    The Walking Dead  Book One (The Walking Dead #...              2
# 2                                      Light in August              2
# 3    Wherever You Go  There You Are: Mindfulness Me...              2
# 4    Captivating: Unveiling the Mystery of a Woman'...              2
# ..                                                 ...            ...
# 995  The World Is Flat: A Brief History of the Twen...              3
# 996                  His Excellency: George Washington              2
# 997                                      Drowning Ruth              3
# 998                                              Junky              2
# 999                               Harvesting the Heart              2
#
#      mean_rating
# 0           5.00
# 1           5.00
# 2           5.00
# 3           5.00
# 4           5.00
# ...

# %% [markdown]
# ### Определим издательство, которое выпустило наибольшее число книг толще 50 страниц — так мы исключим из анализа брошюры

# %%
query = '''SELECT publisher, count(book_id) AS books_count
             FROM (SELECT books.*, publishers.publisher
             FROM books, publishers
             WHERE books.publisher_id = publishers.publisher_id) AS t
             WHERE num_pages > 50
             GROUP BY publisher
             ORDER BY books_count DESC 
             LIMIT 1'''

con=engine.connect()

pd.io.sql.read_sql(sql=text(query), con = con)
# Out:
#        publisher  books_count
# 0  Penguin Books           42

# %% [markdown]
# - Издательство Penguin Books

# %% [markdown]
# ### Определим автора с самой высокой средней оценкой книг — учитываем только книги с 50 и более оценками

# %%
query = '''SELECT authors.author, avg(book_avg_ratings.book_rating_avg) as author_rating_avg
                    FROM books
                    INNER JOIN (SELECT book_id, avg(rating) as book_rating_avg
                                FROM ratings
                                GROUP BY book_id
                                HAVING COUNT(*) >= 50) AS book_avg_ratings
                    ON book_avg_ratings.book_id = books.book_id
                    INNER JOIN authors ON authors.author_id = books.author_id
                    GROUP BY authors.author
                    ORDER BY author_rating_avg desc
             LIMIT 1'''

con=engine.connect()

pd.io.sql.read_sql(sql=text(query), con = con)
# Out:
#                        author  author_rating_avg
# 0  J.K. Rowling/Mary GrandPré           4.283844

# %% [markdown]
# - J.K. Rowling/Mary GrandPré - автор с самой высокой средней оценкой книг

# %% [markdown]
# ### Посчитаем среднее количество обзоров от пользователей, которые поставили больше 48 оценок

# %%
query = '''SELECT AVG(t.count)
           FROM (SELECT total.username, COUNT(total.username)
                 FROM (SELECT username, COUNT(rating_id) AS count
                       FROM ratings
                       GROUP BY username) as total
                 JOIN reviews ON reviews.username = total.username
                 WHERE total.count > 48
                 GROUP BY total.username) as t'''

con=engine.connect()

pd.io.sql.read_sql(sql=text(query), con = con)
# Out:
#     avg
# 0  24.0

# %% [markdown]
# - В среднем 24 обзора

# %% [markdown]
# ## Дополнительные задания

# %% [markdown]
# ### Выведи таблицу, которая будет содержать по году публикации (отобразить нужно только те года, в которых издано более 30 книг):
#
# - количество издательств;
# - выпущенных книг;
# - сколько всего тысяч страниц было в изданных книгах (обрати внимание - ответ нужен в тысячах).

# %% [raw]
# query = '''SELECT EXTRACT(YEAR FROM publication_date::date) AS YEAR, COUNT(book_id)
#            FROM books
#            GROUP BY YEAR
#            HAVING COUNT(book_id) >30
#            ORDER BY YEAR;
#
#
#
#
# '''
#
# con=engine.connect()
#
# pd.io.sql.read_sql(sql=text(query), con = con)

# %% [markdown]
# - Вывели количество книг больше 30 по годам;

# %% [raw]
# query = '''SELECT EXTRACT(YEAR FROM b.publication_date::date) AS YEAR, COUNT(b.book_id) AS count_books, COUNT(DISTINCT p.publisher) AS count_p
#            FROM books AS b
#            JOIN publishers AS p ON b.publisher_id=p.publisher_id
#            GROUP BY YEAR
#            HAVING COUNT(book_id) >30
#            ORDER BY YEAR;
#
#
#
#
# '''
#
# con=engine.connect()
#
# pd.io.sql.read_sql(sql=text(query), con = con)

# %% [markdown]
# - Добавили издательство;

# %%
query = '''SELECT
           EXTRACT(YEAR FROM b.publication_date::date) AS YEAR, COUNT(b.book_id) AS count_books, COUNT(DISTINCT p.publisher) AS count_p, SUM(b.num_pages)/1000 AS sum_pages
           FROM books AS b
           JOIN publishers AS p ON b.publisher_id=p.publisher_id
           GROUP BY YEAR
           HAVING COUNT(book_id) >30 
           ORDER BY YEAR;




'''

con=engine.connect()

pd.io.sql.read_sql(sql=text(query), con = con)
# Out:
#      year  count_books  count_p  sum_pages
# 0  1999.0           41       26         15
# 1  2000.0           38       35         13
# 2  2001.0           60       41         21
# 3  2002.0           94       62         38
# 4  2003.0          105       65         41
# 5  2004.0          124       88         46
# 6  2005.0          139       89         55
# 7  2006.0          184      109         68
# 8  2007.0           50       38         18

# %% [markdown]
# - добавила страницы;

# %% [markdown]
# ### Выведи в одной таблице два числа — среднюю оценку тех книг, на которые написало отзывов более 3 человек и отдельно среднюю оценку остальных книг, сделай выводы, какой рейтинг больше

# %%
query = '''

WITH A AS
  (SELECT 
   AVG(r.rating) avg_rating
   FROM ratings AS r
   JOIN books AS b ON r.book_id=b.book_id
   JOIN reviews AS rw ON b.book_id=rw.book_id
   GROUP BY rw.book_id
   HAVING COUNT(rw.review_id)<=3)
SELECT round (SUM (avg_rating) / COUNT(avg_rating), 2) AS AVG
FROM A;


'''

con=engine.connect()

pd.io.sql.read_sql(sql=text(query), con = con)
# Out:
#     avg
# 0  3.82

# %%
query = '''


   SELECT round ((SUM (avg_rating) / COUNT(avg_rating)), 2) AS AVG
   FROM (SELECT 
              AVG(r.rating) AS avg_rating
         FROM ratings AS r
         JOIN books AS b ON r.book_id=b.book_id
         JOIN reviews AS rw ON b.book_id=rw.book_id   
         GROUP BY rw.book_id
         HAVING COUNT(rw.review_id)>3) AS t;


'''

con=engine.connect()

pd.io.sql.read_sql(sql=text(query), con = con)
# Out:
#    avg
# 0  3.9

# %%
query = '''


SELECT round ((SUM (avg_rating) / COUNT(avg_rating)), 2) AS AVG
FROM (SELECT 
            AVG(r.rating) AS avg_rating
      FROM ratings AS r
      JOIN books AS b ON r.book_id=b.book_id
      JOIN reviews AS rw ON b.book_id=rw.book_id   
      GROUP BY rw.book_id
      HAVING COUNT(rw.review_id)<=3) AS t
UNION
SELECT round ((SUM (avg_rating) / COUNT(avg_rating)), 2) AS AVG
FROM (SELECT 
            AVG(r.rating) AS avg_rating
      FROM ratings AS r
      JOIN books AS b ON r.book_id=b.book_id
      JOIN reviews AS rw ON b.book_id=rw.book_id   
      GROUP BY rw.book_id
      HAVING COUNT(rw.review_id)>3) AS y;


'''

con=engine.connect()

pd.io.sql.read_sql(sql=text(query), con = con)
# Out:
#     avg
# 0  3.82
# 1  3.90

# %%
query = ''' with over_3 as (
SELECT AVG(r.rating) AS avg_rating,
       COUNT(rw.review_id) AS count_reviews
FROM ratings AS r
RIGHT OUTER JOIN BOOKS AS b ON r.book_id=b.book_id
LEFT OUTER JOIN reviews AS rw ON b.book_id = rw.book_id
)
       
SELECT round ((SUM (avg_rating) / COUNT(avg_rating)), 2) AS AVG
FROM over_3
WHERE count_reviews>3;
            
'''

con=engine.connect()

pd.io.sql.read_sql(sql=text(query), con = con)
# Out:
#     avg
# 0  3.94

# %%
query = ''' with less_3 as (
SELECT AVG(r.rating) AS avg_rating,
       COUNT(rw.review_id) AS count_reviews
FROM ratings AS r
RIGHT OUTER JOIN BOOKS AS b ON r.book_id=b.book_id
LEFT OUTER JOIN reviews AS rw ON b.book_id = rw.book_id
)
       
SELECT round ((SUM (avg_rating) / COUNT(avg_rating)), 2) AS AVG
FROM less_3
WHERE count_reviews<=3;
            
'''

con=engine.connect()

pd.io.sql.read_sql(sql=text(query), con = con)
# Out:
#     avg
# 0  None

# %%
query = ''' 
SELECT AVG(r.rating) AS avg_rating,
       COUNT(rw.review_id) AS count_reviews
FROM ratings AS r
RIGHT OUTER JOIN BOOKS AS b ON r.book_id=b.book_id
LEFT OUTER JOIN reviews AS rw ON b.book_id = rw.book_id;
            
'''

con=engine.connect()

pd.io.sql.read_sql(sql=text(query), con = con)
# Out:
#    avg_rating  count_reviews
# 0    3.936784          26167

# %%
query = ''' with less_3 as (
SELECT AVG(r.rating) AS avg_rating,
       COUNT(rw.review_id) AS count_reviews,
       rw.book_id
FROM ratings AS r
RIGHT OUTER JOIN BOOKS AS b ON r.book_id=b.book_id
LEFT OUTER JOIN reviews AS rw ON b.book_id = rw.book_id
GROUP BY rw.book_id
)
       
SELECT round ((SUM (avg_rating) / COUNT(avg_rating)), 2) AS AVG
FROM less_3
WHERE count_reviews<=3;

            
'''

con=engine.connect()

pd.io.sql.read_sql(sql=text(query), con = con)
# Out:
#     avg
# 0  3.82

# %%
query = ''' (with over_3 as (
SELECT AVG(r.rating) AS avg_rating,
       COUNT(rw.review_id) AS count_reviews,
       rw.book_id
FROM ratings AS r
RIGHT OUTER JOIN BOOKS AS b ON r.book_id=b.book_id
LEFT OUTER JOIN reviews AS rw ON b.book_id = rw.book_id
GROUP BY rw.book_id
)
       
SELECT round ((SUM (avg_rating) / COUNT(avg_rating)), 2) AS AVG
FROM over_3
WHERE count_reviews>3)

UNION 

(with less_3 as (
SELECT AVG(r.rating) AS avg_rating,
       COUNT(rw.review_id) AS count_reviews,
       rw.book_id
FROM ratings AS r
RIGHT OUTER JOIN BOOKS AS b ON r.book_id=b.book_id
LEFT OUTER JOIN reviews AS rw ON b.book_id = rw.book_id
GROUP BY rw.book_id
)
       
SELECT round ((SUM (avg_rating) / COUNT(avg_rating)), 2) AS AVG
FROM less_3
WHERE count_reviews<=3);
'''

con=engine.connect()

pd.io.sql.read_sql(sql=text(query), con = con)
# Out:
#     avg
# 0  3.82
# 1  3.90

# %%
query = '''
SELECT AVG(r.rating) AS avg_rating
FROM ratings AS r
LEFT OUTER JOIN reviews AS rw ON r.book_id = rw.book_id
WHERE rw.review_id IN (SELECT rw.book_id
FROM reviews AS rw
GROUP BY rw.book_id
HAVING COUNT(rw.review_id)<=3)

UNION

SELECT AVG(r.rating) AS avg_rating
FROM ratings AS r
LEFT OUTER JOIN reviews AS rw ON r.book_id = rw.book_id
WHERE rw.review_id IN (SELECT rw.book_id
FROM reviews AS rw
GROUP BY rw.book_id
HAVING COUNT(rw.review_id)>3)

'''

con=engine.connect()

pd.io.sql.read_sql(sql=text(query), con = con)
# Out:
#    avg_rating
# 0    3.956522
# 1    3.965728

# %%
query = '''
(with less_3 as(
SELECT AVG(rating) AS avg_rating
FROM (SELECT rw.book_id, count(rw.review_id) AS count_rev, r.rating
     FROM reviews AS rw
     LEFT OUTER JOIN ratings AS r ON rw.book_id = r.book_id
     GROUP BY rw.book_id,r.rating) AS y
WHERE count_rev<=3
GROUP BY book_id)
SELECT round ((SUM (avg_rating) / COUNT(avg_rating)), 2) AS AVG
FROM less_3)

UNION

(with over_3 as(
SELECT AVG(rating) AS avg_rating
FROM (SELECT rw.book_id, count(rw.review_id) AS count_rev, r.rating
     FROM reviews AS rw
     LEFT OUTER JOIN ratings AS r ON rw.book_id = r.book_id
     GROUP BY rw.book_id,r.rating) AS y
WHERE count_rev>3
GROUP BY book_id)
SELECT round ((SUM (avg_rating) / COUNT(avg_rating)), 2) AS AVG
FROM over_3)



'''

con=engine.connect()

pd.io.sql.read_sql(sql=text(query), con = con)
# Out:
#     avg
# 0  3.76
# 1  3.88

# %%
query = '''
(SELECT AVG(rating) AS avg_rating
FROM ratings AS r
LEFT OUTER JOIN reviews AS rw ON r.book_id = rw.book_id
WHERE r.book_id IN (SELECT rw.book_id
FROM reviews AS rw
GROUP BY rw.book_id
HAVING COUNT(rw.review_id)<=3))

UNION

(SELECT AVG(rating) AS avg_rating
FROM ratings AS r
LEFT OUTER JOIN reviews AS rw ON r.book_id = rw.book_id
WHERE r.book_id IN (SELECT rw.book_id
FROM reviews AS rw
GROUP BY rw.book_id
HAVING COUNT(rw.review_id)>3)); 


'''

con=engine.connect()

pd.io.sql.read_sql(sql=text(query), con = con)
# Out:
#    avg_rating
# 0    3.888196
# 1    3.950534

# %%
query = '''
SELECT AVG(rating) AS avg_rating 
FROM ratings AS r
WHERE r.book_id IN (SELECT COUNT(rw.review_id) AS count_reviews
FROM reviews AS rw
GROUP BY rw.book_id
HAVING COUNT(rw.review_id)>3)

UNION

SELECT AVG(rating) AS avg_rating 
FROM ratings AS r
WHERE r.book_id IN (SELECT COUNT(rw.review_id) AS count_reviews
FROM reviews AS rw
GROUP BY rw.book_id
HAVING COUNT(rw.review_id)<=3);


'''

con=engine.connect()

pd.io.sql.read_sql(sql=text(query), con = con)
# Out:
#    avg_rating
# 0    3.666667
# 1    3.750000

# %%
query = '''
(WITH 
first_query AS (SELECT rw.book_id, COUNT(rw.review_id) AS count_reviews
FROM reviews AS rw
GROUP BY rw.book_id
HAVING COUNT(rw.review_id)>3)
SELECT AVG(rating) AS avg_rating 
FROM ratings AS r LEFT OUTER JOIN first_query AS fq ON r.book_id = fq.book_id
WHERE count_reviews>3)

UNION

(WITH 
second_query AS (SELECT rw.book_id, COUNT(rw.review_id) AS count_reviews
FROM reviews AS rw
GROUP BY rw.book_id
HAVING COUNT(rw.review_id)<=3)
SELECT AVG(rating) AS avg_rating 
FROM ratings AS r LEFT OUTER JOIN second_query AS sq ON r.book_id = sq.book_id
WHERE count_reviews<=3);

'''

con=engine.connect()

pd.io.sql.read_sql(sql=text(query), con = con)
# Out:
#    avg_rating
# 0    3.890191
# 1    3.949505

# %% [markdown]
# - Средняя оценка тех книг, на которые написало отзывы более 3 человек на 0,15 балла выше чем средняя оценка тех, книг, у которых отзывов меньше трех.

# %% [markdown]
# ## Выводы

# %% [markdown]
# - После 1 января 2000 года вышло 819 книг;
# - Для каждой книги посчитали количество обзоров от 3 до 1 и среднюю оценку от 5 до 1,5;
# - Издательство, которое выпустило наибольшее число книг толще 50 страниц (так мы исключим из анализа брошюры) Penguin Books	выпустило 42 книги;
# - Автор с самой высокой средней оценкой книг (учитываем только книги с 50 и более оценками) J.K. Rowling/Mary GrandPré	средний рейтинг 4.28;
# - Среднее количество обзоров от пользователей, которые поставили больше 48 оценок составляет 24 обзора.
